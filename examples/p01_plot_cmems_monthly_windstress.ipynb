# %% [markdown]
# # Download, save, and plot data from Copernicus Marine Environment Monitoring Service (CMEMS)
#
# #### Notebook for monthly CMEMS data mapping.

# %%
import os
import xarray as xr

from odspatialmaps import download as dl
from odspatialmaps import plot as pl

import matplotlib as mpl
style = 'seaborn-v0_8-white'
mpl.style.use(style)

# %%
## Set a save dir
project_root = r'/mnt/c/Users/00099894/Large_Data/Other/ECMWF'
save_dir = f'{project_root}/odspatialmaps_setio/cmems/'

# %%
# plot_data = 'monthly_wind_stress'
# plot_data = 'total_currents_glob'
# plot_data = 'geo_currents_glob'
plot_data = 'currents_model'

full_details = dl.get_cmems_details(plot_data)

long_bnds = (94, 136)
lat_bnds = (-25, -5)
time_bnds = ("1994-07-01", "2024-07-01")

depth_range = (0.5, 0.5)

# %%
# cp_download = dl.download_cmems(plot_data,
#                         os.path.join(save_dir, full_details[plot_data]['file_name']),
#                         long_bnds,
#                         lat_bnds,
#                         None,
#                         None)

# save_path = cp_download.file_path.as_posix()

# %% [markdown]
# ## Plot the data
#
# Plot the mean Ekman surface currents in July using the standard package template.

# %%
load_path = os.path.join(save_dir, full_details['file_name'])
ds = xr.open_dataset(load_path)
ds
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:    (time: 731, depth: 1, latitude: 241, longitude: 505)
# Coordinates:
#   * time       (time) datetime64[ns] 6kB 2022-01-01 2022-01-02 ... 2024-01-01
#   * depth      (depth) float32 4B 0.494
#   * latitude   (latitude) float32 964B -25.0 -24.92 -24.83 ... -5.083 -5.0
#   * longitude  (longitude) float32 2kB 94.0 94.08 94.17 ... 135.8 135.9 136.0
# Data variables:
#     uo         (time, depth, latitude, longitude) float64 712MB ...
#     vo         (time, depth, latitude, longitude) float64 712MB ...
# Attributes:
#     title:                     daily mean fields from Global Ocean Physics An...
#     comment:                   CMEMS product
#     references:                http://www.mercator-ocean.fr
#     history:                   2023/06/01 16:20:05 MERCATOR OCEAN Netcdf crea...
#     Conventions:               CF-1.4
#     source:                    MERCATOR GLORYS12V1
#     institution:               MERCATOR OCEAN
# ...

# %%
save_loc = os.path.join(save_dir, plot_data)
if not os.path.isdir(save_loc):
    os.mkdir(save_loc)

# %%
pl.plot_monthly_data(ds, full_details, save_loc, scale=18, thin=12)
# Out:
# /home/wedge/anaconda3/envs/odspatialmaps/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/wedge/anaconda3/envs/odspatialmaps/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/wedge/anaconda3/envs/odspatialmaps/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/wedge/anaconda3/envs/odspatialmaps/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# ...

# %%
pl.plot_monthly_eke(ds, full_details, save_loc)
# Out:
# /home/wedge/anaconda3/envs/odspatialmaps/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/wedge/anaconda3/envs/odspatialmaps/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/wedge/anaconda3/envs/odspatialmaps/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/wedge/anaconda3/envs/odspatialmaps/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# ...
